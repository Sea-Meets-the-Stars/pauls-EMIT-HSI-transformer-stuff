# %%
#import download_just_hypercubes:
# %load_ext autoreload
# %autoreload 2
import download_just_hypercubes as djh
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
granule_ids = djh.search_granule_ids(start_date="2023-01-01", end_date="2023-02-02", cloud_cover_min=0, cloud_cover_max=5, max_granules=10)

# %%
hypercube = djh.download_hypercube(granule_ids[0], temp_dir="./temp_processing/emit_download/")

# %%
plt.imshow(hypercube[:,:,255], cmap='gray', vmin=0)

# %%
chips = djh.chip_hypercube(hypercube, 128)
plt.imshow(chips[0][:,:,255], cmap='gray', vmin=0)
# Out:
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16279
# 15358
# 13488
# 10675
# 7041
# 4515
# 3977
# 5430
# 8835
# 12282
# 14690
# 16050
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 13568
# 9472
# 5376
# 1280
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16241
# 15244
# 13299
# 10405
# 6734
# 3635
# 1494
# 956
# 2386
# 5145
# 8906
# 12338
# 14722
# 16059
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 16384
# 13568
# 9472
# 5376
# ...
